# %% [markdown]
# # Arbeitspaket (AP) 3: Management & Nutzung Räumliche Daten

# %% [markdown]
# ### Angaben Studierende(r) (fehlende Angaben ergänzen)

# %% [markdown]
# <table>
#   <tr>
#     <td>Vorname:</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Nachname:</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Immatrikulationsnummer:</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Modul:</td>
#     <td>Data Science</td>
#   </tr>
#   <tr>
#     <td>Prüfungsdatum / Raum / Zeit:</td>
#     <td>07.10.2024 / Raum: SF O3.54 / 8:00 – 11:45</td>
#   </tr>
#   <tr>
#     <td>Erlaubte Hilfsmittel:</td>
#     <td>w.MA.XX.DS.24HS (Data Science)<br>Open Book, Eigener Computer, Internet-Zugang</td>
#   </tr>
#   <tr>
#   <td>Nicht erlaubt:</td>
#   <td>Nicht erlaubt ist der Einsatz beliebiger Formen von generativer KI (z.B. Copilot, ChatGPT) <br> sowie beliebige Formen von Kommunikation oder Kollaboration mit anderen Menschen.</td>
# </tr>
# </table>

# %% [markdown]
# ## Bewertungskriterien
#
# ### <b style="color: gray;">(max. erreichbare Punkte: 48)</b>
#
# <table>
#   <thead>
#     <tr>
#       <th>Kategorie</th>
#       <th>Beschreibung</th>
#       <th>Punkteverteilung</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Code nicht lauffähig oder Ergebnisse nicht sinnvoll</td>
#       <td>Der Code enthält Fehler, die verhindern, dass er ausgeführt werden kann (z.B. Syntaxfehler) oder es werden Ergebnisse ausgegeben, welche nicht zur Fragestellung passen.</td>
#       <td>0 Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig, aber mit gravierenden Mängeln</td>
#       <td>Der Code läuft, aber die Ergebnisse sind aufgrund wesentlicher Fehler unvollständig (z.B. fehlende Joins, gravierende Fehler in SQL-Abfragen). Nur geringer Fortschritt erkennbar.</td>
#       <td>25% der max. erreichbaren Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig, aber mit mittleren Mängeln</td>
#       <td>Der Code läuft und liefert teilweise korrekte Ergebnisse, aber es gibt grössere Fehler (z.B. fehlende Spalten, unvollständige SQL-Abfragen). Die Ergebnisse sind nachvollziehbar, aber unvollständig oder ungenau.</td>
#       <td>50% der max. erreichbaren Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig, aber mit minimalen Mängeln</td>
#       <td>Der Code läuft und liefert ein weitgehend korrektes Ergebnis, aber kleinere Fehler (z.B. falsche oder fehlende Sortierung, Rundung von Werten falsch) beeinträchtigen die Vollständigkeit des Ergebnisses.</td>
#       <td>75% der max. erreichbaren Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig und korrekt</td>
#       <td>Der Code läuft einwandfrei und liefert das korrekte Ergebnis ohne Mängel.</td>
#       <td>100% der max. erreichbaren Punkte</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### <b>Python Libraries und Settings</b>

# %%
# Libraries
import os
import folium
import pandas as pd
import geopandas as gpd
from sqlalchemy import create_engine, text

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

print(os.getcwd())
# Out:
# /workspaces/python_postgresql_postgis

# %% [markdown]
# ## <b>Vorbereitung (Hinweis: dieser Teil wird <u>nicht</u> bewertet)</b>

# %% [markdown]
# #### <b>1.) Starten Sie eine GitHub Codespaces Instanz auf Basis Ihres Forks des folgenden GitHub Repositories:</b>
#
# ##### GitHub-Repository: https://github.com/mario-gellrich-zhaw/python_postgresql_postgis
#
# ##### <span style="color: red;"><b>WICHTIG!!! Verwenden Sie eine GitHub Codespaces Instanz mit ausreichend Arbeitsspeicher (4core, 16GB RAM).</b></span>
#
# <b>Hinweis:</b>
# - Im Unterricht wurden bereits sämtliche Installationen und Einstellungen inkl. der Registrierung des Datenbank Servers auf pgAdmin vorgenommen.
# - Falls Sie die Codespaces-Instanz neu erstellen müssen, folgen Sie bitte den detaillierten Erklärungen auf der README-Seite des GitHub Repositories.

# %% [markdown]
# #### <b>2.) Erstellen und Testen Sie die Datenbankverbindung mit der 'osm_switzerland' Datenbank.</b>

# %%
# Set up Database Connection
user = "pgadmin"
password = "geheim"
host = "localhost"
port = "5432"
database = "osm_switzerland"

# Erstellen der Connection URL
db_connection_url = "postgresql://" + user + ":" + password +\
                    "@" + host + ":" + port + "/" + database

# Erstellen SQLAlchemy Engine
engine = create_engine(db_connection_url)

# Test der Connection
with engine.connect() as connection:
    result = connection.execute(text('SELECT current_database()'))
    print(result.fetchone())

# Verbindung trennen
engine.dispose()
# Out:
# ('osm_switzerland',)

# %% [markdown]
# ## <b>Aufgaben (Dieser Teil wird bewertet!)</b>
# <b>Hinweise zu den folgenden Aufgabenstellungen:</b>
# <ul>
#   <li>In diesem Jupyter Notebook gibt es jeweils zwei Code-Zellen pro Aufgabe:</li>
#   <ol>
#     <li>Eine Codezelle mit Python-Code und einem SQL-Statement für die Datenbank-Abfrage.</li>
#     <li>Eine Codezelle mit Python-Code für die Kartendarstellung der Ergebnisse der jeweiligen SQL-Abfrage.</li>
#   </ol>
#   <li>In den Codezellen für die Datenbank-Abfrage muss jeweils das SQL-Statement ergänzt werden.</li>
#   <li>In den Codezellen für die Kartendarstellung muss nur dann der Python Code ergänzt werden, wenn in der Aufgabe danach gefragt wird.</li>
# </ul>
# <b style="color:red;">Beachten Sie, dass für die Punktevergabe auch die weiteren Anforderungen zu den Fragen unter 'Details zur Aufgabenstellung' herangezogen werden.</b>

# %% [markdown]
# #### <b>Aufgabe (1): Erstellen Sie eine Abfrage sämtlicher Autoreparatur-Werkstätten.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in der Tabelle 'planet_osm_point'.
# - Stellen sie in der Ergebnistabelle die Spalten: osm_id, shop sowie die transformierte Geometrie als Spalte geom dar.
# - Tipp: Die Geometry wird mit Hilfe der Funktion st_transform() transformiert, z.B.: *st_transform(p.way, 4326) AS geom*.
# - Tipp: Autoreparatur-Werkstätten sind mit dem key:value Paar shop='car_repair' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p.shop,
            st_transform(p.way, 4236) AS geom
         FROM
            planet_osm_point AS p
         WHERE p.shop = 'car_repair';"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#           osm_id        shop                      geom
# 0     7390840334  car_repair  POINT (8.84883 47.24984)
# 1     1157271363  car_repair  POINT (8.92461 47.32693)
# 2     6178457132  car_repair  POINT (8.85788 47.39365)
# 3    11053970252  car_repair  POINT (8.85242 47.41491)
# 4    11053970256  car_repair  POINT (8.85265 47.41475)
# ..           ...         ...                       ...
# 297   6424049579  car_repair  POINT (8.39132 47.45672)
# 298   2929805340  car_repair  POINT (8.43628 47.55826)
# 299  12855181247  car_repair  POINT (8.82441 47.53764)
# 300  12850641833  car_repair  POINT (8.82512 47.53741)
# 301  12855181248  car_repair  POINT (8.82444 47.53758)
#
# [302 rows x 3 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=10, 
               tiles='CartoDB positron')

# Map settings
folium.GeoJson(
    gdf,
    name='map'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e636b97b231cd058aa9df5ec86a3b0b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e636b97b231cd058aa9df5ec86a3b0b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e636b97b231cd058aa9df5ec86a3b0b9 = L.map(
#                 &quot;map_e636b97b231cd058aa9df5ec86a3b0b9&quot;,
#                 {
#                     center: [47.38913619276393, 8.624466402409666],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_29773c5a65b09aa7363b31baed8c287d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_29773c5a65b09aa7363b31baed8c287d.addTo(map_e636b97b231cd058aa9df5ec86a3b0b9);
#
#
#
#         function geo_json_ee5ecc5a03a8508fc26bccde6a259654_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_ee5ecc5a03a8508fc26bccde6a259654 = L.geoJson(null, {
#                 onEachFeature: geo_json_ee5ecc5a03a8508fc26bccde6a259654_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_ee5ecc5a03a8508fc26bccde6a259654_add (data) {
#             geo_json_ee5ecc5a03a8508fc26bccde6a259654
#                 .addData(data);
#         }
#             geo_json_ee5ecc5a03a8508fc26bccde6a259654_add({&quot;bbox&quot;: [8.37591589955681, 47.19164847896554, 8.918742303407111, 47.64363038050689], &quot;features&quot;: [{&quot;bbox&quot;: [8.84295430313818, 47.252491580161205, 8.84295430313818, 47.252491580161205], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.84295430313818, 47.252491580161205], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 7390840334, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.918742303407111, 47.32959918093413, 8.918742303407111, 47.32959918093413], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.918742303407111, 47.32959918093413], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 1157271363, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.85199720280475, 47.39632068085119, 8.85199720280475, 47.39632068085119], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.85199720280475, 47.39632068085119], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 6178457132, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.846534602712577, 47.41758058091406, 8.846534602712577, 47.41758058091406], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.846534602712577, 47.41758058091406], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 11053970252, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.846756102714405, 47.41742378091463, 8.846756102714405, 47.41742378091463], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.846756102714405, 47.41742378091463], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 11053970256, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.84583920264814, 47.43967448100755, 8.84583920264814, 47.43967448100755], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.84583920264814, 47.43967448100755], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 3097655049, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.869417902641228, 47.49690258139325, 8.869417902641228, 47.49690258139325], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.869417902641228, 47.49690258139325], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 12002475355, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.773422302021629, 47.502696580872964, 8.773422302021629, 47.502696580872964], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.773422302021629, 47.502696580872964], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;7&quot;, &quot;properties&quot;: {&quot;osm_id&quot;

# %% [markdown]
# #### <b>Aufgabe (2) Erstellen Sie eine Abfrage aller Biergärten.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in den Tabellen 'planet_osm_point'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, amenity, name und die transformierte Geometrie als Spalte geom dar.
# - Tipp: Biergärten sind mit dem key:value Paar amenity='biergarten' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p.amenity,
            p.name,
            st_transform(p.way::geometry, 4326) AS geom
         FROM planet_osm_point AS p
         WHERE
            p.amenity = 'biergarten'
     ;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf.head()
# Out:
#        osm_id     amenity            name                      geom
# 0   768907979  biergarten    Engel Lounge  POINT (8.67547 47.23005)
# 1  2518707388  biergarten  zum Adlerhorst  POINT (8.68977 47.38973)
# 2  2679062372  biergarten  Gamschtä Träff  POINT (8.76787 47.23535)

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=8, 
               tiles='CartoDB positron')

# Map settings
folium.GeoJson(
    gdf,
    name='map'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_28e6a3763b107e3bb675cbf85177712c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_28e6a3763b107e3bb675cbf85177712c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_28e6a3763b107e3bb675cbf85177712c = L.map(
#                 &quot;map_28e6a3763b107e3bb675cbf85177712c&quot;,
#                 {
#                     center: [47.28504446676764, 8.711035866666665],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_878bcf3d13303248e28a952510b2fc44 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_878bcf3d13303248e28a952510b2fc44.addTo(map_28e6a3763b107e3bb675cbf85177712c);
#
#
#
#         function geo_json_39e5c47df0701d4bf32e42fc19364759_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_39e5c47df0701d4bf32e42fc19364759 = L.geoJson(null, {
#                 onEachFeature: geo_json_39e5c47df0701d4bf32e42fc19364759_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_39e5c47df0701d4bf32e42fc19364759_add (data) {
#             geo_json_39e5c47df0701d4bf32e42fc19364759
#                 .addData(data);
#         }
#             geo_json_39e5c47df0701d4bf32e42fc19364759_add({&quot;bbox&quot;: [8.6754669, 47.23005180011294, 8.767871899999998, 47.38973230007818], &quot;features&quot;: [{&quot;bbox&quot;: [8.6754669, 47.23005180011294, 8.6754669, 47.23005180011294], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.6754669, 47.23005180011294], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;amenity&quot;: &quot;biergarten&quot;, &quot;name&quot;: &quot;Engel Lounge&quot;, &quot;osm_id&quot;: 768907979}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.6897688, 47.38973230007818, 8.6897688, 47.38973230007818], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.6897688, 47.38973230007818], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;amenity&quot;: &quot;biergarten&quot;, &quot;name&quot;: &quot;zum Adlerhorst&quot;, &quot;osm_id&quot;: 2518707388}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.767871899999998, 47.235349300111814, 8.767871899999998, 47.235349300111814], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.767871899999998, 47.235349300111814], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;amenity&quot;: &quot;biergarten&quot;, &quot;name&quot;: &quot;Gamscht\u00e4 Tr\u00e4ff&quot;, &quot;osm_id&quot;: 2679062372}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_39e5c47df0701d4bf32e42fc19364759.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_39e5c47df0701d4bf32e42fc19364759.addTo(map_28e6a3763b107e3bb675cbf85177712c);
#
#
#             var layer_control_a9b545324bad02e36038f892374f6041_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_878bcf3d13303248e28a952510b2fc44,
#                 },
#                 overlays :  {
#                     &quot;map&quot; : geo_json_39e5c47df0701d4bf32e42fc19364759,
#                 },
#             };
#             let layer_control_a9b545324bad02e36038f892374f6041 = L.control.layers(
#                 layer_control_a9b545324bad02e36038f892374f6041_layers.base_layers,
#                 layer_control_a9b545324bad02e36038f892374f6041_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_28e6a3763b107e3bb675cbf85177712c);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### <b>Aufgabe (3): Erstellen Sie eine Abfrage aller Gebäude in der Stadthausstrasse in Winterthur, welche vollständige Adressangaben besitzen.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in der Tabelle 'planet_osm_polygon'.
# - Vollständige Adressangabe bedeutet: Strassenname, Haunummer, PLZ, Gemeindename sind vorhanden.
# - Stellen Sie in der Ergebnistabelle sämtliche Adressangaben sowie die transformierte Geometrie als Spalte geom dar.
# - Verwenden Sie für die Darstellung als Hintergrundkarte ein Satellitenbild (ESRIWorldImagery) als maptile.
# - Tipp: Gebäude sind in der Spalte 'building' klassifiziert. Mit *WHERE building IS NOT NULL* können Sie Gebäude filtern.
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p."addr:street",
            p."addr:housenumber",
            p."addr:city",
            p."addr:postcode",
            st_transform(p.way, 4326) AS geom
         FROM
            planet_osm_polygon AS p
         WHERE
            p.building IS NOT NULL
            AND p."addr:street" = 'Stadthausstrasse'
            AND p."addr:housenumber" IS NOT NULL
            AND p."addr:postcode" IS NOT NULL
            AND p."addr:city" IS NOT NULL
     ;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#        osm_id       addr:street addr:housenumber   addr:city addr:postcode  \
# 0     9264543  Stadthausstrasse               4a  Winterthur          8400
# 1    22301937  Stadthausstrasse                4  Winterthur          8400
# 2    75027485  Stadthausstrasse               31  Winterthur          8400
# 3    75027472  Stadthausstrasse               35  Winterthur          8400
# 4    75027503  Stadthausstrasse               37  Winterthur          8400
# ..        ...               ...              ...         ...           ...
# 56   94283231  Stadthausstrasse              145  Winterthur          8400
# 57   94283304  Stadthausstrasse              143  Winterthur          8400
# 58   24804763  Stadthausstrasse               22  Winterthur          8400
# 59   26992511  Stadthausstrasse               24  Winterthur          8400
# 60  134980581  Stadthausstrasse              10b  Winterthur          8400
#
#                                                  geom
# 0   POLYGON ((8.73111 47.50115, 8.73112 47.50085, ...
# 1   POLYGON ((8.73232 47.50109, 8.73233 47.50107, ...
# 2   POLYGON ((8.73162 47.50041, 8.73165 47.50029, ...
# 3   POLYGON ((8.73153 47.5004, 8.73157 47.50026, 8...
# 4   POLYGON ((8.73146 47.5004, 8.73149 47.50028, 8...
# ..                                                ...
# 56  POLYGON ((8.72414 47.4995, 8.72417 47.49939, 8...
# 57  POLYGON ((8.72427 47.49952, 8.72431 47.4994, 8...
# 58  POLYGON ((8.72448 47.49982, 8.72453 47.4997, 8...
# 59  POLYGON ((8.72405 47.49972, 8.72407 47.49967, ...
# 60  POLYGON ((8.72652 47.50075, 8.72661 47.50063, ...
#
# [61 rows x 6 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=17, 
               tiles='CartoDB positron')

#wenn Satellit verwendet werden soll, einfach mit tiles = 'ESRIWorldImagery' ersetzen

# Map settings
folium.Choropleth(
    geo_data=gdf,
    name='map',
    fill_color='greenyellow'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_076b9a70ed530be2ded4032f6abe910d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_076b9a70ed530be2ded4032f6abe910d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_076b9a70ed530be2ded4032f6abe910d = L.map(
#                 &quot;map_076b9a70ed530be2ded4032f6abe910d&quot;,
#                 {
#                     center: [47.500044957105665, 8.727995077567487],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 17,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_846fcf5e69102db6795263d5dc6b58c0 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_846fcf5e69102db6795263d5dc6b58c0.addTo(map_076b9a70ed530be2ded4032f6abe910d);
#
#
#             var choropleth_a0b6edf6e29e45f4e5c5462bc6aca943 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_2e8bafffa2adc15031bf46f090446554_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;greenyellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_2e8bafffa2adc15031bf46f090446554_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_2e8bafffa2adc15031bf46f090446554 = L.geoJson(null, {
#                 onEachFeature: geo_json_2e8bafffa2adc15031bf46f090446554_onEachFeature,
#
#                 style: geo_json_2e8bafffa2adc15031bf46f090446554_styler,
#             ...{
# }
#         });
#
#         function geo_json_2e8bafffa2adc15031bf46f090446554_add (data) {
#             geo_json_2e8bafffa2adc15031bf46f090446554
#                 .addData(data);
#         }
#             geo_json_2e8bafffa2adc15031bf46f090446554_add({&quot;bbox&quot;: [8.724050699999998, 47.49938870005378, 8.733014099999998, 47.50121620005338], &quot;features&quot;: [{&quot;bbox&quot;: [8.7311112, 47.50077290005347, 8.7316854, 47.50121620005338], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.7311112, 47.50115050005339], [8.731123300000002, 47.50085480005345], [8.7312761, 47.500857700053466], [8.7312755, 47.50087160005346], [8.731299299999998, 47.50087210005346], [8.7313035, 47.50077290005347], [8.73141, 47.50077500005347], [8.7315165, 47.500777000053475], [8.7315124, 47.50087680005345], [8.7315354, 47.50087730005343], [8.7315359, 47.500864200053456], [8.7316854, 47.500867000053454], [8.7316733, 47.50116300005338], [8.731542999999999, 47.50116060005339], [8.731541199999999, 47.501205700053376], [8.731498599999998, 47.50120500005339], [8.7314982, 47.50121620005338], [8.731284999999998, 47.50121210005338], [8.731285500000002, 47.501200100053396], [8.7312367, 47.50119930005338], [8.7312387, 47.5011529000534], [8.7311112, 47.50115050005339]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Winterthur&quot;, &quot;addr:housenumber&quot;: &quot;4a&quot;, &quot;addr:postcode&quot;: &quot;8400&quot;, &quot;addr:street&quot;: &quot;Stadthausstrasse&quot;, &quot;osm_id&quot;: 9264543}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.732324799999999, 47.500817500053465, 8.733014099999998, 47.501177600053374], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.732324799999999, 47.501085000053415], [8.732325800000002, 47.501067900053414], [8.7323502, 47.50106850005342], [8.7323541, 47.50099720005342], [8.732536199999998, 47.501001700053436], [8.7325365, 47.50099630005342], [8.7325632, 47.50099690005343], [8.7325628, 47.50100460005343], [8.7326588, 47.50100700005344], [8.7326584, 47.50101520005343], [8.732682900000002, 47.50101590005343], [8.7326848, 47.50101110005343], [8.7326879, 47.501006800053425], [8.7326924, 47.50100220005344], [8.732696399999998, 47.50099880005343], [8.732702499999998, 47.50099550005342], [8.7327095, 47.50099330005342], [8.7327178, 47.50099190005342], [8.7327258, 47.50099130005342], [8.7327344, 47.50099230005341], [8.7327427, 47.50099440005343], [8.7327497, 47.50099720005342], [8.732755899999999, 47.50100090005342], [8.7327598, 47.50100490005342], [8.7327632, 47.50101000005342], [8.7327651, 47.501014300053434], [8.732767, 47.50101970005343], [8.7327923, 47.50101980005342], [8.7328054, 47.500828400053464], [8.7328606, 47.50083010005347], [8.732896, 47.500831200053454], [8.732896699999998, 47.500817500053465], [8.7

# %% [markdown]
# #### <b>Aufgabe (4): Erstellen Sie eine Abfrage aller Strassen welche als 'motorway' klassifiziert sind.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Informationen in der Tabelle 'planet_osm_roads'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, highway und die transformierte Geometrie als Spalte geom dar.
# - Tipp: Motorways sind mit dem key:value Paar highway='motorway' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p.highway,
            st_transform(p.way::geometry, 4326) AS geom
         FROM
            planet_osm_roads AS p
         WHERE
            p.highway = 'motorway'
     ;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#          osm_id   highway                                               geom
# 0     546365250  motorway     LINESTRING (8.83096 47.26077, 8.8309 47.26063)
# 1     546365251  motorway    LINESTRING (8.83104 47.26094, 8.83096 47.26077)
# 2      40528299  motorway    LINESTRING (8.83122 47.26097, 8.83134 47.26125)
# 3      40528306  motorway    LINESTRING (8.83116 47.26122, 8.83104 47.26094)
# 4     546365253  motorway  LINESTRING (8.8314 47.2618, 8.83129 47.26153, ...
# ...         ...       ...                                                ...
# 1133   41257924  motorway    LINESTRING (8.83087 47.55204, 8.83061 47.55192)
# 1134   43586264  motorway  LINESTRING (8.82692 47.54965, 8.82747 47.55003...
# 1135   41257915  motorway  LINESTRING (8.83061 47.55192, 8.83024 47.55175...
# 1136   43586284  motorway    LINESTRING (8.82684 47.54959, 8.82692 47.54965)
# 1137   43586259  motorway     LINESTRING (8.82672 47.54966, 8.82664 47.5496)
#
# [1138 rows x 3 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=10, 
               tiles='CartoDB positron')

# Map settings
folium.Choropleth(
    geo_data=gdf,
    name='map',
    line_weight=3,
    line_color='red'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_23aa17405a912ee09c8449057b245b3b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_23aa17405a912ee09c8449057b245b3b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_23aa17405a912ee09c8449057b245b3b = L.map(
#                 &quot;map_23aa17405a912ee09c8449057b245b3b&quot;,
#                 {
#                     center: [47.390590215388556, 8.58229609138885],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f8a6bb647aae1ec1d5e30689038457a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2f8a6bb647aae1ec1d5e30689038457a.addTo(map_23aa17405a912ee09c8449057b245b3b);
#
#
#             var choropleth_1fdba865aafbb933b497fea8354b2228 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_521c64fad9a563baf348e0a9a6d728d4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_521c64fad9a563baf348e0a9a6d728d4_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_521c64fad9a563baf348e0a9a6d728d4 = L.geoJson(null, {
#                 onEachFeature: geo_json_521c64fad9a563baf348e0a9a6d728d4_onEachFeature,
#
#                 style: geo_json_521c64fad9a563baf348e0a9a6d728d4_styler,
#             ...{
# }
#         });
#
#         function geo_json_521c64fad9a563baf348e0a9a6d728d4_add (data) {
#             geo_json_521c64fad9a563baf348e0a9a6d728d4
#                 .addData(data);
#         }
#             geo_json_521c64fad9a563baf348e0a9a6d728d4_add({&quot;bbox&quot;: [8.3632475, 47.19620480012019, 8.9032688, 47.56752360003842], &quot;features&quot;: [{&quot;bbox&quot;: [8.8308994, 47.26063240010636, 8.830962599999998, 47.260768900106335], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.830962599999998, 47.260768900106335], [8.8308994, 47.26063240010636]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 546365250}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.830962599999998, 47.260768900106335, 8.8310407, 47.260935100106295], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8310407, 47.260935100106295], [8.830962599999998, 47.260768900106335]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 546365251}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8312169, 47.260969100106294, 8.831339299999998, 47.26124960010623], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8312169, 47.260969100106294], [8.831339299999998, 47.26124960010623]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 40528299}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8310407, 47.260935100106295, 8.8311646, 47.26121720010624], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8311646, 47.26121720010624], [8.8310407, 47.260935100106295]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 40528306}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8311646, 47.26121720010624, 8.8313998, 47.26180450010611], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8313998, 47.26180450010611], [8.8312908, 47.261525300106165], [8.8311646, 47.26121720010624]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 546365253}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8321748, 47.26389860010566, 8.832219099999998, 47.26411770010561], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8321748, 47.26389860010566], [8.832219099999998, 47.26411770010561]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 546365255}, &quot;typ

# %% [markdown]
# #### <b>Aufgabe (5): Erstellen Sie eine Abfrage aller Flüsse. Generieren Sie zusätzlich Buffer um die Flüsse mit einer Breite von 2000m.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Informationen in der Tabelle 'planet_osm_line'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, waterway sowie die transformierte Geometrie als Spalte geom dar.
# - Tipp: Flüsse sind mit dem key:value Paar waterway='river' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
# - Tipp: Per Default wird für jedes Fluss-Segment ein separater Buffer erstellt. Es ist nicht notwendig daraus einen einzelnen Buffer zu generieren.
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p.waterway,
            st_transform(p.way::geometry, 4328) AS geom
         FROM
            planet_osm_line AS p
         WHERE
            p.waterway = 'river'
     ;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#          osm_id waterway                                               geom
# 0      33606198    river  LINESTRING (4286333.43054 667766.52795, 428637...
# 1      33605947    river  LINESTRING (4283558.3847 670097.27925, 4283552...
# 2     315137969    river  LINESTRING (4282698.35925 671561.34169, 428273...
# 3    1284695711    river  LINESTRING (4283992.80628 668237.16087, 428400...
# 4     668843910    river  LINESTRING (4284243.1205 667754.20043, 4284263...
# ..          ...      ...                                                ...
# 230  1337145281    river  LINESTRING (4253677.96954 644561.81663, 425365...
# 231  1337145284    river  LINESTRING (4253677.96954 644561.81663, 425364...
# 232  1337145285    river  LINESTRING (4253636.06932 644451.97812, 425363...
# 233    12373075    river  LINESTRING (4257376.29434 669360.21158, 425737...
# 234   833353743    river  LINESTRING (4258959.89857 656827.87301, 425897...
#
# [235 rows x 3 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=10, 
               tiles='CartoDB positron')

# Map settings
folium.Choropleth(
    geo_data=gdf,
    name='map',
    fill_color='greenyellow'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32e7c0339981bda777ef0573ae6c9cff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32e7c0339981bda777ef0573ae6c9cff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32e7c0339981bda777ef0573ae6c9cff = L.map(
#                 &quot;map_32e7c0339981bda777ef0573ae6c9cff&quot;,
#                 {
#                     center: [655580.3668288997, 4274369.703725544],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_395496130b2afd21d6fedf3c54e91b45 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_395496130b2afd21d6fedf3c54e91b45.addTo(map_32e7c0339981bda777ef0573ae6c9cff);
#
#
#             var choropleth_c14eb8508af8f41c08b721ee1332a8b0 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_56d0a42cdb943ee7ae9a2c30994b0176_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;greenyellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_56d0a42cdb943ee7ae9a2c30994b0176_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_56d0a42cdb943ee7ae9a2c30994b0176 = L.geoJson(null, {
#                 onEachFeature: geo_json_56d0a42cdb943ee7ae9a2c30994b0176_onEachFeature,
#
#                 style: geo_json_56d0a42cdb943ee7ae9a2c30994b0176_styler,
#             ...{
# }
#         });
#
#         function geo_json_56d0a42cdb943ee7ae9a2c30994b0176_add (data) {
#             geo_json_56d0a42cdb943ee7ae9a2c30994b0176
#                 .addData(data);
#         }
#             geo_json_56d0a42cdb943ee7ae9a2c30994b0176_add({&quot;bbox&quot;: [8.1468199, 0.0, 8.9602562, 0.0], &quot;features&quot;: [{&quot;bbox&quot;: [8.834491, 0.0, 8.854911700000002, 0.0], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.854911700000002, 0.0], [8.8534593, 0.0], [8.853021099999998, 0.0], [8.851649999999998, 0.0], [8.8509867, 0.0], [8.850368700000002, 0.0], [8.8500089, 0.0], [8.849646199999999, 0.0], [8.8490991, 0.0], [8.848574799999998, 0.0], [8.848121800000001, 0.0], [8.847686800000002, 0.0], [8.8473849, 0.0], [8.8471445, 0.0], [8.8469058, 0.0], [8.846633999999998, 0.0], [8.846341999999998, 0.0], [8.845982399999999, 0.0], [8.845221999999996, 0.0], [8.844629699999999, 0.0], [8.844398299999998, 0.0], [8.844009899999998, 0.0], [8.8438053, 0.0], [8.843556200000002, 0.0], [8.8433465, 0.0], [8.843104600000002, 0.0], [8.8428181, 0.0], [8.842542700000001, 0.0], [8.8422698, 0.0], [8.842001800000002, 0.0], [8.8417315, 0.0], [8.841455099999997, 0.0], [8.841185199999998, 0.0], [8.8408317, 0.0], [8.8405694, 0.0], [8.8403527, 0.0], [8.840162199999998, 0.0], [8.8397391, 0.0], [8.839466099999997, 0.0], [8.839402399999999, 0.0], [8.83932, 0.0], [8.839008099999997, 0.0], [8.838823399999999, 0.0], [8.8386823, 0.0], [8.8385095, 0.0], [8.837559999999996, 0.0], [8.8374746, 0.0], [8.837367300000002, 0.0], [8.836972, 0.0], [8.836864699999996, 0.0], [8.836758500000002, 0.0], [8.8366512, 0.0], [8.8365335, 0.0], [8.835374199999999, 0.0], [8.8352488, 0.0], [8.8351446, 0.0], [8.8350512, 0.0], [8.834967299999999, 0.0], [8.834894200000003, 0.0], [8.8348395, 0.0], [8.8348128, 0.0], [8.834774200000002, 0.0], [8.8347194, 0.0], [8.834513899999997, 0.0], [8.834491, 0.0], [8.834499699999999, 0.0], [8.834536700000001, 0.0], [8.8346045, 0.0], [8.8346837, 0.0], [8.8348258, 0.0], [8.8349657, 0.0], [8.835103900000002, 0.0], [8.835222999999997, 0.0], [8.8353841, 0.0], [8.8358693, 0.0], [8.8359888, 0.0], [8.836107900000002, 0.0], [8.836745100000002, 0.0]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 33606198, &quot;waterway&quot;: &quot;river&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8590026, 0.0, 8.890990600000002, 0.0], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.890990600000002, 0.0], [8.890356599999999, 0.0], [8.890045200000001, 0.0], [8.8890992, 0.0], [8.888688500000002, 0.0], [8.8879946, 0.0], [8.887744699999999, 0.0], [8.8874832, 0.0], [8.8867457, 0.0], [8.886132899999996, 0.0], [8.88583, 0.0], [8.885411499999998, 0.0], [8.885161600000002, 0.0], [8.8845466, 0.0], [8.883975900000001, 0.0], [8.883388399999998, 0.0], [8.883144599999996, 0.

# %% [markdown]
# #### <b>Aufgabe (6): Erstellen Sie eine Abfrage der Bäckerei-Geschäfte in Zürich und Winterthur.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in den Tabellen 'planet_osm_point' (Backereien).
# - Verwenden Sie die Städtenamen aus den Adressangaben für die Abfrage der Bäckerei-Standorte (Zürich, Winterthur).
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, shop, name, "addr:city" sowie die transformierte Geometrie als geom dar.
# - Wählen Sie eine Satelliten Karte von ESRI als Hintergrundkarte (maptile).
# - Sortieren Sie die Bäckerei-Geschäfte aufsteigend nach osm_id.
# - Tipp: Bäckerei-Geschäfte sind mit dem key:value Paar shop='bakery' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
         FROM
         WHERE
     ;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=12, 
               tiles='CartoDB positron')

# Map settings
folium.GeoJson(
    gdf,
    name='map',
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m

# %% [markdown]
# #### <b>Aufgabe (7): Erstellen Sie eine Abfrage sämtlicher Coiffeur-Geschäfte in einem Radius von 500m um den Hauptbahnhof in Zürich.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die Daten in der Tabelle 'planet_osm_point'.
# - Berechnen Sie in der Abfrage die Distanz jedes Coiffeur-Geschäfts zum Hauptbahnhof in Metern als Spalte 'distance_meters'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, shop, name, distance_meters, sowie die transformierte Geometrie als geom dar.
# - Wählen Sie eine Satelliten Karte von ESRI als Hintergrundkarte (maptile).
# - Integrieren Sie in die Kartendarstellung den Namen (Spalte 'name') der Coiffeur-Geschäfte als Popup.
# - Tipp: Coiffeur-Geschäfte sind mit dem key:value Paar shop='hairdresser' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
         FROM
         WHERE
     ;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf.head()

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=16, 
               tiles='CartoDB positron')

# Map settings
folium.GeoJson(
    gdf,
    name='map'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('IP Address:', socket.gethostbyname(socket.gethostname()))
print('-----------------------------------')
