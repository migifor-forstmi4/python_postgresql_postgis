# %% [markdown]
# # Arbeitspaket (AP) 3: Management & Nutzung Räumliche Daten

# %% [markdown]
# ### Angaben Studierende(r) (fehlende Angaben ergänzen)

# %% [markdown]
# <table>
#   <tr>
#     <td>Vorname:</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Nachname:</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Immatrikulationsnummer:</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Modul:</td>
#     <td>Data Science</td>
#   </tr>
#   <tr>
#     <td>Prüfungsdatum / Raum / Zeit:</td>
#     <td>07.10.2024 / Raum: SF O3.54 / 8:00 – 11:45</td>
#   </tr>
#   <tr>
#     <td>Erlaubte Hilfsmittel:</td>
#     <td>w.MA.XX.DS.24HS (Data Science)<br>Open Book, Eigener Computer, Internet-Zugang</td>
#   </tr>
#   <tr>
#   <td>Nicht erlaubt:</td>
#   <td>Nicht erlaubt ist der Einsatz beliebiger Formen von generativer KI (z.B. Copilot, ChatGPT) <br> sowie beliebige Formen von Kommunikation oder Kollaboration mit anderen Menschen.</td>
# </tr>
# </table>

# %% [markdown]
# ## Bewertungskriterien
#
# ### <b style="color: gray;">(max. erreichbare Punkte: 48)</b>
#
# <table>
#   <thead>
#     <tr>
#       <th>Kategorie</th>
#       <th>Beschreibung</th>
#       <th>Punkteverteilung</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Code nicht lauffähig oder Ergebnisse nicht sinnvoll</td>
#       <td>Der Code enthält Fehler, die verhindern, dass er ausgeführt werden kann (z.B. Syntaxfehler) oder es werden Ergebnisse ausgegeben, welche nicht zur Fragestellung passen.</td>
#       <td>0 Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig, aber mit gravierenden Mängeln</td>
#       <td>Der Code läuft, aber die Ergebnisse sind aufgrund wesentlicher Fehler unvollständig (z.B. fehlende Joins, gravierende Fehler in SQL-Abfragen). Nur geringer Fortschritt erkennbar.</td>
#       <td>25% der max. erreichbaren Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig, aber mit mittleren Mängeln</td>
#       <td>Der Code läuft und liefert teilweise korrekte Ergebnisse, aber es gibt grössere Fehler (z.B. fehlende Spalten, unvollständige SQL-Abfragen). Die Ergebnisse sind nachvollziehbar, aber unvollständig oder ungenau.</td>
#       <td>50% der max. erreichbaren Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig, aber mit minimalen Mängeln</td>
#       <td>Der Code läuft und liefert ein weitgehend korrektes Ergebnis, aber kleinere Fehler (z.B. falsche oder fehlende Sortierung, Rundung von Werten falsch) beeinträchtigen die Vollständigkeit des Ergebnisses.</td>
#       <td>75% der max. erreichbaren Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig und korrekt</td>
#       <td>Der Code läuft einwandfrei und liefert das korrekte Ergebnis ohne Mängel.</td>
#       <td>100% der max. erreichbaren Punkte</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### <b>Python Libraries und Settings</b>

# %%
# Libraries
import os
import folium
import pandas as pd
import geopandas as gpd
from sqlalchemy import create_engine, text

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

print(os.getcwd())
# Out:
# /workspaces/python_postgresql_postgis

# %% [markdown]
# ## <b>Vorbereitung (Hinweis: dieser Teil wird <u>nicht</u> bewertet)</b>

# %% [markdown]
# #### <b>1.) Starten Sie eine GitHub Codespaces Instanz auf Basis Ihres Forks des folgenden GitHub Repositories:</b>
#
# ##### GitHub-Repository: https://github.com/mario-gellrich-zhaw/python_postgresql_postgis
#
# ##### <span style="color: red;"><b>WICHTIG!!! Verwenden Sie eine GitHub Codespaces Instanz mit ausreichend Arbeitsspeicher (4core, 16GB RAM).</b></span>
#
# <b>Hinweis:</b>
# - Im Unterricht wurden bereits sämtliche Installationen und Einstellungen inkl. der Registrierung des Datenbank Servers auf pgAdmin vorgenommen.
# - Falls Sie die Codespaces-Instanz neu erstellen müssen, folgen Sie bitte den detaillierten Erklärungen auf der README-Seite des GitHub Repositories.

# %% [markdown]
# #### <b>2.) Erstellen und Testen Sie die Datenbankverbindung mit der 'osm_switzerland' Datenbank.</b>

# %%
# Set up Database Connection
user = "pgadmin"
password = "geheim"
host = "localhost"
port = "5432"
database = "osm_switzerland"

# Erstellen der Connection URL
db_connection_url = "postgresql://" + user + ":" + password +\
                    "@" + host + ":" + port + "/" + database

# Erstellen SQLAlchemy Engine
engine = create_engine(db_connection_url)

# Test der Connection
with engine.connect() as connection:
    result = connection.execute(text('SELECT current_database()'))
    print(result.fetchone())

# Verbindung trennen
engine.dispose()
# Out:
# ('osm_switzerland',)

# %% [markdown]
# ## <b>Aufgaben (Dieser Teil wird bewertet!)</b>
# <b>Hinweise zu den folgenden Aufgabenstellungen:</b>
# <ul>
#   <li>In diesem Jupyter Notebook gibt es jeweils zwei Code-Zellen pro Aufgabe:</li>
#   <ol>
#     <li>Eine Codezelle mit Python-Code und einem SQL-Statement für die Datenbank-Abfrage.</li>
#     <li>Eine Codezelle mit Python-Code für die Kartendarstellung der Ergebnisse der jeweiligen SQL-Abfrage.</li>
#   </ol>
#   <li>In den Codezellen für die Datenbank-Abfrage muss jeweils das SQL-Statement ergänzt werden.</li>
#   <li>In den Codezellen für die Kartendarstellung muss nur dann der Python Code ergänzt werden, wenn in der Aufgabe danach gefragt wird.</li>
# </ul>
# <b style="color:red;">Beachten Sie, dass für die Punktevergabe auch die weiteren Anforderungen zu den Fragen unter 'Details zur Aufgabenstellung' herangezogen werden.</b>

# %% [markdown]
# #### <b>Aufgabe (1): Erstellen Sie eine Abfrage sämtlicher Autoreparatur-Werkstätten.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in der Tabelle 'planet_osm_point'.
# - Stellen sie in der Ergebnistabelle die Spalten: osm_id, shop sowie die transformierte Geometrie als Spalte geom dar.
# - Tipp: Die Geometry wird mit Hilfe der Funktion st_transform() transformiert, z.B.: *st_transform(p.way, 4326) AS geom*.
# - Tipp: Autoreparatur-Werkstätten sind mit dem key:value Paar shop='car_repair' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p.shop,
            st_transform(p.way, 4236) AS geom
         FROM
            planet_osm_point AS p
         WHERE p.shop = 'car_repair';"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#           osm_id        shop                      geom
# 0     7390840334  car_repair  POINT (8.84883 47.24984)
# 1     1157271363  car_repair  POINT (8.92461 47.32693)
# 2    12164274376  car_repair  POINT (8.77159 47.51316)
# 3     4879747542  car_repair  POINT (8.79461 47.49664)
# 4     4818397954  car_repair  POINT (8.72518 47.50206)
# ..           ...         ...                       ...
# 297  12247129014  car_repair  POINT (8.68805 47.56246)
# 298  12247136015  car_repair  POINT (8.68989 47.56259)
# 299  12855181247  car_repair  POINT (8.82441 47.53764)
# 300  12850641833  car_repair  POINT (8.82512 47.53741)
# 301  12855181248  car_repair  POINT (8.82444 47.53758)
#
# [302 rows x 3 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=10, 
               tiles='CartoDB positron')

# Map settings
folium.GeoJson(
    gdf,
    name='map'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c659a9206923458cae5ae7ba381381f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c659a9206923458cae5ae7ba381381f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c659a9206923458cae5ae7ba381381f = L.map(
#                 &quot;map_9c659a9206923458cae5ae7ba381381f&quot;,
#                 {
#                     center: [47.38913619276392, 8.624466402409666],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ee6243ffdf9798e28a75e3d37d5f1ec = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9ee6243ffdf9798e28a75e3d37d5f1ec.addTo(map_9c659a9206923458cae5ae7ba381381f);
#
#
#
#         function geo_json_20db6e641994ecaa044cac9b05da1937_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_20db6e641994ecaa044cac9b05da1937 = L.geoJson(null, {
#                 onEachFeature: geo_json_20db6e641994ecaa044cac9b05da1937_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_20db6e641994ecaa044cac9b05da1937_add (data) {
#             geo_json_20db6e641994ecaa044cac9b05da1937
#                 .addData(data);
#         }
#             geo_json_20db6e641994ecaa044cac9b05da1937_add({&quot;bbox&quot;: [8.37591589955681, 47.19164847896554, 8.918742303407111, 47.64363038050689], &quot;features&quot;: [{&quot;bbox&quot;: [8.84295430313818, 47.252491580161205, 8.84295430313818, 47.252491580161205], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.84295430313818, 47.252491580161205], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 7390840334, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.918742303407111, 47.32959918093413, 8.918742303407111, 47.32959918093413], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.918742303407111, 47.32959918093413], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 1157271363, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.765679501937289, 47.5158373808865, 8.765679501937289, 47.5158373808865], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.765679501937289, 47.5158373808865], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 12164274376, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.788696702126584, 47.499321380945034, 8.788696702126584, 47.499321380945034], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.788696702126584, 47.499321380945034], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 4879747542, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.719262401677527, 47.50473528057369, 8.719262401677527, 47.50473528057369], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.719262401677527, 47.50473528057369], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 4818397954, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.724374501703364, 47.506952180612494, 8.724374501703364, 47.506952180612494], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.724374501703364, 47.506952180612494], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 4347235409, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.70550740158288, 47.50799978050968, 8.70550740158288, 47.50799978050968], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.70550740158288, 47.50799978050968], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 6248779785, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.68240080142055, 47.514774280407764, 8.68240080142055, 47.514774280407764], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.68240080142055, 47.514774280407764], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;7&quot;, &quot;properties&quot;: {&quot;osm_id&quot

# %% [markdown]
# #### <b>Aufgabe (2) Erstellen Sie eine Abfrage aller Biergärten.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in den Tabellen 'planet_osm_point'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, amenity, name und die transformierte Geometrie als Spalte geom dar.
# - Tipp: Biergärten sind mit dem key:value Paar amenity='biergarten' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p.amenity,
            p.name,
            st_transform(p.way::geometry, 4326) AS geom
         FROM planet_osm_point AS p
         WHERE
            p.amenity = 'biergarten'
     ;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf.head()
# Out:
#        osm_id     amenity            name                      geom
# 0  2518707388  biergarten  zum Adlerhorst  POINT (8.68977 47.38973)
# 1  2679062372  biergarten  Gamschtä Träff  POINT (8.76787 47.23535)
# 2   768907979  biergarten    Engel Lounge  POINT (8.67547 47.23005)

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=8, 
               tiles='CartoDB positron')

# Map settings
folium.GeoJson(
    gdf,
    name='map'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c4777c23b1d08fa4d3a0d516899bc65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c4777c23b1d08fa4d3a0d516899bc65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c4777c23b1d08fa4d3a0d516899bc65 = L.map(
#                 &quot;map_9c4777c23b1d08fa4d3a0d516899bc65&quot;,
#                 {
#                     center: [47.28504446676764, 8.711035866666666],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51d3d00f463c9fb819463e2a59e74b12 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_51d3d00f463c9fb819463e2a59e74b12.addTo(map_9c4777c23b1d08fa4d3a0d516899bc65);
#
#
#
#         function geo_json_68e331365a5523b6028381af4e4a44b6_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_68e331365a5523b6028381af4e4a44b6 = L.geoJson(null, {
#                 onEachFeature: geo_json_68e331365a5523b6028381af4e4a44b6_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_68e331365a5523b6028381af4e4a44b6_add (data) {
#             geo_json_68e331365a5523b6028381af4e4a44b6
#                 .addData(data);
#         }
#             geo_json_68e331365a5523b6028381af4e4a44b6_add({&quot;bbox&quot;: [8.6754669, 47.23005180011294, 8.767871899999998, 47.38973230007818], &quot;features&quot;: [{&quot;bbox&quot;: [8.6897688, 47.38973230007818, 8.6897688, 47.38973230007818], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.6897688, 47.38973230007818], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;amenity&quot;: &quot;biergarten&quot;, &quot;name&quot;: &quot;zum Adlerhorst&quot;, &quot;osm_id&quot;: 2518707388}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.767871899999998, 47.235349300111814, 8.767871899999998, 47.235349300111814], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.767871899999998, 47.235349300111814], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;amenity&quot;: &quot;biergarten&quot;, &quot;name&quot;: &quot;Gamscht\u00e4 Tr\u00e4ff&quot;, &quot;osm_id&quot;: 2679062372}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.6754669, 47.23005180011294, 8.6754669, 47.23005180011294], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.6754669, 47.23005180011294], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;amenity&quot;: &quot;biergarten&quot;, &quot;name&quot;: &quot;Engel Lounge&quot;, &quot;osm_id&quot;: 768907979}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_68e331365a5523b6028381af4e4a44b6.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_68e331365a5523b6028381af4e4a44b6.addTo(map_9c4777c23b1d08fa4d3a0d516899bc65);
#
#
#             var layer_control_e000434e64327d265d97ed869820cc41_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_51d3d00f463c9fb819463e2a59e74b12,
#                 },
#                 overlays :  {
#                     &quot;map&quot; : geo_json_68e331365a5523b6028381af4e4a44b6,
#                 },
#             };
#             let layer_control_e000434e64327d265d97ed869820cc41 = L.control.layers(
#                 layer_control_e000434e64327d265d97ed869820cc41_layers.base_layers,
#                 layer_control_e000434e64327d265d97ed869820cc41_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_9c4777c23b1d08fa4d3a0d516899bc65);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### <b>Aufgabe (3): Erstellen Sie eine Abfrage aller Gebäude in der Stadthausstrasse in Winterthur, welche vollständige Adressangaben besitzen.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in der Tabelle 'planet_osm_polygon'.
# - Vollständige Adressangabe bedeutet: Strassenname, Haunummer, PLZ, Gemeindename sind vorhanden.
# - Stellen Sie in der Ergebnistabelle sämtliche Adressangaben sowie die transformierte Geometrie als Spalte geom dar.
# - Verwenden Sie für die Darstellung als Hintergrundkarte ein Satellitenbild (ESRIWorldImagery) als maptile.
# - Tipp: Gebäude sind in der Spalte 'building' klassifiziert. Mit *WHERE building IS NOT NULL* können Sie Gebäude filtern.
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p."addr:street",
            p."addr:housenumber",
            p."addr:city",
            p."addr:postcode",
            st_transform(p.way, 4326) AS geom
         FROM
            planet_osm_polygon AS p
         WHERE
            p.building IS NOT NULL
            AND p."addr:street" = 'Stadthausstrasse'
            AND p."addr:housenumber" IS NOT NULL
            AND p."addr:postcode" IS NOT NULL
            AND p."addr:city" IS NOT NULL
     ;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#        osm_id       addr:street addr:housenumber   addr:city addr:postcode  \
# 0     9264543  Stadthausstrasse               4a  Winterthur          8400
# 1    22301937  Stadthausstrasse                4  Winterthur          8400
# 2   230520582  Stadthausstrasse               41  Winterthur          8400
# 3   230520584  Stadthausstrasse               43  Winterthur          8400
# 4   230520586  Stadthausstrasse               45  Winterthur          8400
# ..        ...               ...              ...         ...           ...
# 56  230520592  Stadthausstrasse               53  Winterthur          8400
# 57   94283231  Stadthausstrasse              145  Winterthur          8400
# 58   94283304  Stadthausstrasse              143  Winterthur          8400
# 59   24804763  Stadthausstrasse               22  Winterthur          8400
# 60   26992511  Stadthausstrasse               24  Winterthur          8400
#
#                                                  geom
# 0   POLYGON ((8.73111 47.50115, 8.73112 47.50085, ...
# 1   POLYGON ((8.73232 47.50109, 8.73233 47.50107, ...
# 2   POLYGON ((8.73055 47.5003, 8.73057 47.50017, 8...
# 3   POLYGON ((8.7304 47.50029, 8.73043 47.50017, 8...
# 4   POLYGON ((8.73024 47.50028, 8.73027 47.50016, ...
# ..                                                ...
# 56  POLYGON ((8.73002 47.50026, 8.73004 47.50013, ...
# 57  POLYGON ((8.72414 47.4995, 8.72417 47.49939, 8...
# 58  POLYGON ((8.72427 47.49952, 8.72431 47.4994, 8...
# 59  POLYGON ((8.72448 47.49982, 8.72453 47.4997, 8...
# 60  POLYGON ((8.72405 47.49972, 8.72407 47.49967, ...
#
# [61 rows x 6 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=17, 
               tiles='CartoDB positron')

#wenn Satellit verwendet werden soll, einfach mit tiles = 'ESRIWorldImagery' ersetzen

# Map settings
folium.Choropleth(
    geo_data=gdf,
    name='map',
    fill_color='greenyellow'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47aae2ab9048682a040badc3e9742525 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47aae2ab9048682a040badc3e9742525&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_47aae2ab9048682a040badc3e9742525 = L.map(
#                 &quot;map_47aae2ab9048682a040badc3e9742525&quot;,
#                 {
#                     center: [47.50004495710567, 8.727995077567487],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 17,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c74fb2d4294ad18a582fca28cc7d30b7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c74fb2d4294ad18a582fca28cc7d30b7.addTo(map_47aae2ab9048682a040badc3e9742525);
#
#
#             var choropleth_59b91aaca69288d57c608ece22b4a023 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_57055558aa31c9353e51c29255577967_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;greenyellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_57055558aa31c9353e51c29255577967_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_57055558aa31c9353e51c29255577967 = L.geoJson(null, {
#                 onEachFeature: geo_json_57055558aa31c9353e51c29255577967_onEachFeature,
#
#                 style: geo_json_57055558aa31c9353e51c29255577967_styler,
#             ...{
# }
#         });
#
#         function geo_json_57055558aa31c9353e51c29255577967_add (data) {
#             geo_json_57055558aa31c9353e51c29255577967
#                 .addData(data);
#         }
#             geo_json_57055558aa31c9353e51c29255577967_add({&quot;bbox&quot;: [8.724050699999998, 47.49938870005378, 8.733014099999998, 47.50121620005338], &quot;features&quot;: [{&quot;bbox&quot;: [8.7311112, 47.50077290005347, 8.7316854, 47.50121620005338], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.7311112, 47.50115050005339], [8.731123300000002, 47.50085480005345], [8.7312761, 47.500857700053466], [8.7312755, 47.50087160005346], [8.731299299999998, 47.50087210005346], [8.7313035, 47.50077290005347], [8.73141, 47.50077500005347], [8.7315165, 47.500777000053475], [8.7315124, 47.50087680005345], [8.7315354, 47.50087730005343], [8.7315359, 47.500864200053456], [8.7316854, 47.500867000053454], [8.7316733, 47.50116300005338], [8.731542999999999, 47.50116060005339], [8.731541199999999, 47.501205700053376], [8.731498599999998, 47.50120500005339], [8.7314982, 47.50121620005338], [8.731284999999998, 47.50121210005338], [8.731285500000002, 47.501200100053396], [8.7312367, 47.50119930005338], [8.7312387, 47.5011529000534], [8.7311112, 47.50115050005339]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Winterthur&quot;, &quot;addr:housenumber&quot;: &quot;4a&quot;, &quot;addr:postcode&quot;: &quot;8400&quot;, &quot;addr:street&quot;: &quot;Stadthausstrasse&quot;, &quot;osm_id&quot;: 9264543}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.732324799999999, 47.500817500053465, 8.733014099999998, 47.501177600053374], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.732324799999999, 47.501085000053415], [8.732325800000002, 47.501067900053414], [8.7323502, 47.50106850005342], [8.7323541, 47.50099720005342], [8.732536199999998, 47.501001700053436], [8.7325365, 47.50099630005342], [8.7325632, 47.50099690005343], [8.7325628, 47.50100460005343], [8.7326588, 47.50100700005344], [8.7326584, 47.50101520005343], [8.732682900000002, 47.50101590005343], [8.7326848, 47.50101110005343], [8.7326879, 47.501006800053425], [8.7326924, 47.50100220005344], [8.732696399999998, 47.50099880005343], [8.732702499999998, 47.50099550005342], [8.7327095, 47.50099330005342], [8.7327178, 47.50099190005342], [8.7327258, 47.50099130005342], [8.7327344, 47.50099230005341], [8.7327427, 47.50099440005343], [8.7327497, 47.50099720005342], [8.732755899999999, 47.50100090005342], [8.7327598, 47.50100490005342], [8.7327632, 47.50101000005342], [8.7327651, 47.501014300053434], [8.732767, 47.50101970005343], [8.7327923, 47.50101980005342], [8.7328054, 47.500828400053464], [8.7328606, 47.50083010005347], [8.732896, 47.500831200053454], [8.732896699999998, 47.500817500053465], [8.73

# %% [markdown]
# #### <b>Aufgabe (4): Erstellen Sie eine Abfrage aller Strassen welche als 'motorway' klassifiziert sind.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Informationen in der Tabelle 'planet_osm_roads'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, highway und die transformierte Geometrie als Spalte geom dar.
# - Tipp: Motorways sind mit dem key:value Paar highway='motorway' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p.highway,
            st_transform(p.way::geometry, 4326) AS geom
         FROM
            planet_osm_roads AS p
         WHERE
            p.highway = 'motorway'
     ;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#          osm_id   highway                                               geom
# 0     546365250  motorway     LINESTRING (8.83096 47.26077, 8.8309 47.26063)
# 1     546365251  motorway    LINESTRING (8.83104 47.26094, 8.83096 47.26077)
# 2      40528299  motorway    LINESTRING (8.83122 47.26097, 8.83134 47.26125)
# 3      40528306  motorway    LINESTRING (8.83116 47.26122, 8.83104 47.26094)
# 4     546365253  motorway  LINESTRING (8.8314 47.2618, 8.83129 47.26153, ...
# ...         ...       ...                                                ...
# 1133  701858643  motorway  LINESTRING (8.55593 47.40347, 8.55485 47.4031,...
# 1134   32278429  motorway  LINESTRING (8.55144 47.40154, 8.55188 47.40176...
# 1135   10621374  motorway  LINESTRING (8.55228 47.40205, 8.55185 47.40187...
# 1136  257237950  motorway  LINESTRING (8.55013 47.40093, 8.55108 47.4014,...
# 1137   32278426  motorway  LINESTRING (8.55133 47.40162, 8.55109 47.40148...
#
# [1138 rows x 3 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=10, 
               tiles='CartoDB positron')

# Map settings
folium.Choropleth(
    geo_data=gdf,
    name='map',
    line_weight=3,
    line_color='red'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e4a2e25d9540028f3f986683d342499 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e4a2e25d9540028f3f986683d342499&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e4a2e25d9540028f3f986683d342499 = L.map(
#                 &quot;map_8e4a2e25d9540028f3f986683d342499&quot;,
#                 {
#                     center: [47.39059021538855, 8.582296091388848],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_093bd5789311f2edfaaf48f0a07cf90f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_093bd5789311f2edfaaf48f0a07cf90f.addTo(map_8e4a2e25d9540028f3f986683d342499);
#
#
#             var choropleth_6f80ca419a0cd5dd5f5bdb9e7d17c5f2 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_0ce80bcc7edfd2791b7ee8b886ab386b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_0ce80bcc7edfd2791b7ee8b886ab386b_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_0ce80bcc7edfd2791b7ee8b886ab386b = L.geoJson(null, {
#                 onEachFeature: geo_json_0ce80bcc7edfd2791b7ee8b886ab386b_onEachFeature,
#
#                 style: geo_json_0ce80bcc7edfd2791b7ee8b886ab386b_styler,
#             ...{
# }
#         });
#
#         function geo_json_0ce80bcc7edfd2791b7ee8b886ab386b_add (data) {
#             geo_json_0ce80bcc7edfd2791b7ee8b886ab386b
#                 .addData(data);
#         }
#             geo_json_0ce80bcc7edfd2791b7ee8b886ab386b_add({&quot;bbox&quot;: [8.3632475, 47.19620480012019, 8.9032688, 47.56752360003842], &quot;features&quot;: [{&quot;bbox&quot;: [8.8308994, 47.26063240010636, 8.830962599999998, 47.260768900106335], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.830962599999998, 47.260768900106335], [8.8308994, 47.26063240010636]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 546365250}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.830962599999998, 47.260768900106335, 8.8310407, 47.260935100106295], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8310407, 47.260935100106295], [8.830962599999998, 47.260768900106335]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 546365251}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8312169, 47.260969100106294, 8.831339299999998, 47.26124960010623], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8312169, 47.260969100106294], [8.831339299999998, 47.26124960010623]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 40528299}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8310407, 47.260935100106295, 8.8311646, 47.26121720010624], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8311646, 47.26121720010624], [8.8310407, 47.260935100106295]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 40528306}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8311646, 47.26121720010624, 8.8313998, 47.26180450010611], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8313998, 47.26180450010611], [8.8312908, 47.261525300106165], [8.8311646, 47.26121720010624]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 546365253}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8321748, 47.26389860010566, 8.832219099999998, 47.26411770010561], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8321748, 47.26389860010566], [8.832219099999998, 47.26411770010561]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 546365255}, &quot;typ

# %% [markdown]
# #### <b>Aufgabe (5): Erstellen Sie eine Abfrage aller Flüsse. Generieren Sie zusätzlich Buffer um die Flüsse mit einer Breite von 2000m.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Informationen in der Tabelle 'planet_osm_line'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, waterway sowie die transformierte Geometrie als Spalte geom dar.
# - Tipp: Flüsse sind mit dem key:value Paar waterway='river' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
# - Tipp: Per Default wird für jedes Fluss-Segment ein separater Buffer erstellt. Es ist nicht notwendig daraus einen einzelnen Buffer zu generieren.
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p.waterway,
            st_transform(p.way::geometry, 4326) AS geom
         FROM
            planet_osm_line AS p
         WHERE
            p.waterway = 'river'
     ;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#          osm_id waterway                                               geom
# 0      33606198    river  LINESTRING (8.85491 47.24121, 8.85346 47.24093...
# 1    1188517700    river  LINESTRING (8.8513 47.26029, 8.85072 47.26015,...
# 2    1074007606    river  LINESTRING (8.85622 47.24134, 8.8562 47.24137,...
# 3      33605947    river  LINESTRING (8.89099 47.27039, 8.89036 47.27055...
# 4     315137969    river  LINESTRING (8.91187 47.27802, 8.91154 47.27756...
# ..          ...      ...                                                ...
# 230  1337145285    river    LINESTRING (8.61514 47.67895, 8.61504 47.67897)
# 231   151615630    river  LINESTRING (8.61656 47.67704, 8.61617 47.67735...
# 232    12373075    river  LINESTRING (8.93511 47.5877, 8.93266 47.58807,...
# 233   833353743    river  LINESTRING (8.76723 47.59213, 8.76552 47.59219...
# 234   303315231    river  LINESTRING (8.60376 47.64146, 8.60439 47.64218...
#
# [235 rows x 3 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=10, 
               tiles='CartoDB positron')

# Map settings
folium.Choropleth(
    geo_data=gdf,
    name='map',
    fill_color='greenyellow'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71d7a11f7f00087307c4e773a72e44d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71d7a11f7f00087307c4e773a72e44d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71d7a11f7f00087307c4e773a72e44d6 = L.map(
#                 &quot;map_71d7a11f7f00087307c4e773a72e44d6&quot;,
#                 {
#                     center: [47.40839891371359, 8.719777316575726],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46a25dfc4b13f775795fbcc82d2b5a3e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_46a25dfc4b13f775795fbcc82d2b5a3e.addTo(map_71d7a11f7f00087307c4e773a72e44d6);
#
#
#             var choropleth_6cd5e14f1ddca1416dedf0ee3fc665da = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_8dc2de33a823af875503de6b4612473a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;greenyellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_8dc2de33a823af875503de6b4612473a_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_8dc2de33a823af875503de6b4612473a = L.geoJson(null, {
#                 onEachFeature: geo_json_8dc2de33a823af875503de6b4612473a_onEachFeature,
#
#                 style: geo_json_8dc2de33a823af875503de6b4612473a_styler,
#             ...{
# }
#         });
#
#         function geo_json_8dc2de33a823af875503de6b4612473a_add (data) {
#             geo_json_8dc2de33a823af875503de6b4612473a
#                 .addData(data);
#         }
#             geo_json_8dc2de33a823af875503de6b4612473a_add({&quot;bbox&quot;: [8.146819899999999, 47.166855700126426, 8.9602562, 47.69560000000913], &quot;features&quot;: [{&quot;bbox&quot;: [8.834491, 47.2367761001115, 8.8549117, 47.242099100110366], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8549117, 47.24121080011055], [8.8534593, 47.240933900110605], [8.8530211, 47.24083190011064], [8.851649999999998, 47.240363500110725], [8.850986699999998, 47.24011290011077], [8.8503687, 47.23991640011082], [8.850008899999999, 47.23981320011086], [8.849646199999999, 47.23974680011085], [8.8490991, 47.23968240011088], [8.8485748, 47.2396334001109], [8.8481218, 47.23960280011089], [8.8476868, 47.23958660011089], [8.8473849, 47.2395934001109], [8.8471445, 47.23962440011089], [8.8469058, 47.23967910011086], [8.846633999999998, 47.23976190011085], [8.846341999999998, 47.23987120011084], [8.8459824, 47.2400317001108], [8.845221999999998, 47.24043830011073], [8.8446297, 47.24083410011062], [8.844398299999998, 47.24102510011059], [8.844009899999998, 47.241442300110506], [8.8438053, 47.241610900110466], [8.8435562, 47.24177010011043], [8.8433465, 47.241863100110415], [8.8431046, 47.24194480011039], [8.8428181, 47.24202360011038], [8.8425427, 47.24207600011036], [8.8422698, 47.242099100110366], [8.8420018, 47.24209340011036], [8.8417315, 47.24206940011037], [8.841455099999997, 47.24200950011039], [8.841185199999998, 47.24192650011039], [8.8408317, 47.24178760011041], [8.8405694, 47.24166620011045], [8.8403527, 47.24153370011048], [8.840162199999998, 47.2413911001105], [8.8397391, 47.24103640011059], [8.8394661, 47.24085080011062], [8.839402399999999, 47.24081990011063], [8.83932, 47.24079030011064], [8.839008099999997, 47.24069450011065], [8.838823399999999, 47.24061770011067], [8.8386823, 47.24054210011069], [8.8385095, 47.24043420011072], [8.837559999999998, 47.239772800110856], [8.8374746, 47.23971740011087], [8.8373673, 47.239659400110874], [8.836972, 47.239481400110925], [8.836864699999998, 47.23944490011094], [8.836758500000002, 47.23941470011094], [8.8366512, 47.239394400110946], [8.836533499999998, 47.239375000110954], [8.835374199999999, 47.23930760011096], [8.8352488, 47.23929260011095], [8.8351446, 47.23927050011097], [8.8350512, 47.23923390011098], [8.8349673, 47.239180200111], [8.8348942, 47.23909230011099], [8.8348395, 47.23900040011103], [8.8348128, 47.23890080011105], [8.8347742, 47.23861490011111], [8.8347194, 47.238221800111184], [8.834513899999997, 47.23744950011136], [8.834491, 47.23731950011138], [8.834499699999999, 47.23719600011142], [8.8345367, 47.237098300111434], [8.8346045, 47.236998900111466], [8.8346837, 47.2369257001

# %% [markdown]
# #### <b>Aufgabe (6): Erstellen Sie eine Abfrage der Bäckerei-Geschäfte in Zürich und Winterthur.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in den Tabellen 'planet_osm_point' (Backereien).
# - Verwenden Sie die Städtenamen aus den Adressangaben für die Abfrage der Bäckerei-Standorte (Zürich, Winterthur).
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, shop, name, "addr:city" sowie die transformierte Geometrie als geom dar.
# - Wählen Sie eine Satelliten Karte von ESRI als Hintergrundkarte (maptile).
# - Sortieren Sie die Bäckerei-Geschäfte aufsteigend nach osm_id.
# - Tipp: Bäckerei-Geschäfte sind mit dem key:value Paar shop='bakery' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            h.osm_id,
            h.shop,
            h.name,
            h."addr:city",
            st_transform(h.way::geometry, 4236) AS geom
         FROM
            planet_osm_point h
         WHERE
            h.shop = 'bakery'
         AND
            h."addr:city" IN ('Zürich', 'Winterthur')
         ORDER BY h.osm_id ASC
     ;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#           osm_id    shop                  name addr:city  \
# 0      252457457  bakery  Steiner Flughafebeck    Zürich
# 1      266630770  bakery           Brezelkönig    Zürich
# 2      267879346  bakery       Walter Buchmann    Zürich
# 3      268602152  bakery               Moser's    Zürich
# 4      270794699  bakery            John Baker    Zürich
# ..           ...     ...                   ...       ...
# 102  10884168277  bakery              Juliette    Zürich
# 103  10946043353  bakery         Babu's Bakery    Zürich
# 104  10955852823  bakery          Täglich Brot    Zürich
# 105  11951988149  bakery                Wagner    Zürich
# 106  12368630564  bakery                 Tsugi    Zürich
#
#                          geom
# 0    POINT (8.50374 47.40045)
# 1     POINT (8.4947 47.38882)
# 2    POINT (8.52504 47.35993)
# 3    POINT (8.55538 47.36055)
# 4    POINT (8.57238 47.36227)
# ..                        ...
# 102  POINT (8.53874 47.36393)
# 103  POINT (8.52162 47.37207)
# 104  POINT (8.51299 47.35814)
# 105  POINT (8.52357 47.36715)
# 106  POINT (8.53686 47.39064)
#
# [107 rows x 5 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=12, 
               tiles='CartoDB positron')

# Map settings
folium.GeoJson(
    gdf,
    name='map',
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0cbe10a59ac95153c6d529ad2acaac76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0cbe10a59ac95153c6d529ad2acaac76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0cbe10a59ac95153c6d529ad2acaac76 = L.map(
#                 &quot;map_0cbe10a59ac95153c6d529ad2acaac76&quot;,
#                 {
#                     center: [47.39222315639798, 8.561919912236712],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8868770fb706fca3b10004e06c922802 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8868770fb706fca3b10004e06c922802.addTo(map_0cbe10a59ac95153c6d529ad2acaac76);
#
#
#
#         function geo_json_f0159de8554393b37f21dd5e1b56eb94_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_f0159de8554393b37f21dd5e1b56eb94 = L.geoJson(null, {
#                 onEachFeature: geo_json_f0159de8554393b37f21dd5e1b56eb94_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_f0159de8554393b37f21dd5e1b56eb94_add (data) {
#             geo_json_f0159de8554393b37f21dd5e1b56eb94
#                 .addData(data);
#         }
#             geo_json_f0159de8554393b37f21dd5e1b56eb94_add({&quot;bbox&quot;: [8.481047800477238, 47.33904537870964, 8.762583502004174, 47.51028558082196], &quot;features&quot;: [{&quot;bbox&quot;: [8.497791600588428, 47.40310627886561, 8.497791600588428, 47.40310627886561], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.497791600588428, 47.40310627886561], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Steiner Flughafebeck&quot;, &quot;osm_id&quot;: 252457457, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.488752400565149, 47.39146777876283, 8.488752400565149, 47.39146777876283], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.488752400565149, 47.39146777876283], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Brezelk\u00f6nig&quot;, &quot;osm_id&quot;: 266630770, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.519103300829881, 47.36258407880862, 8.519103300829881, 47.36258407880862], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.519103300829881, 47.36258407880862], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Walter Buchmann&quot;, &quot;osm_id&quot;: 267879346, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.549451801014149, 47.36320137898427, 8.549451801014149, 47.36320137898427], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.549451801014149, 47.36320137898427], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Moser\u0027s&quot;, &quot;osm_id&quot;: 268602152, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.566451501113814, 47.364925179088715, 8.566451501113814, 47.364925179088715], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.566451501113814, 47.364925179088715], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;John Baker&quot;, &quot;osm_id&quot;: 270794699, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.554053901024984, 47.36955897903853, 8.554053901024984, 47.36955897903853], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.554053901024984, 47.36955897903853], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Caf\u00e9 Berner&quot;, &quot;osm_id&quot;: 270799257, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.731394401767709, 47.49943308061952, 8.731394401767709, 47.49943308061952], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.

# %% [markdown]
# #### <b>Aufgabe (7): Erstellen Sie eine Abfrage sämtlicher Coiffeur-Geschäfte in einem Radius von 500m um den Hauptbahnhof in Zürich.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die Daten in der Tabelle 'planet_osm_point'.
# - Berechnen Sie in der Abfrage die Distanz jedes Coiffeur-Geschäfts zum Hauptbahnhof in Metern als Spalte 'distance_meters'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, shop, name, distance_meters, sowie die transformierte Geometrie als geom dar.
# - Wählen Sie eine Satelliten Karte von ESRI als Hintergrundkarte (maptile).
# - Integrieren Sie in die Kartendarstellung den Namen (Spalte 'name') der Coiffeur-Geschäfte als Popup.
# - Tipp: Coiffeur-Geschäfte sind mit dem key:value Paar shop='hairdresser' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p.shop,
            p.name,
            ST_Distance(
                ST_Transform(p.way, 4326)::geography,
                ST_SetSRID(ST_MakePoint(8.5393635, 47.3781008), 4326)::geography
            ) AS distance_meters,
            ST_Transform(p.way, 4326) AS geom        
         FROM
            planet_osm_point AS p
         WHERE
            p.shop = 'hairdresser'
            AND ST_DWithin(
                ST_Transform(p.way, 4326)::geography,
                ST_SetSRID(ST_MakePoint(8.5393635, 47.3781008), 4326)::geography,
                500
        )
        ORDER BY distance_meters;"""


#mit ST_Distance(...) AS distance_meters berechent die Entfernung in Metern zwischen Suche und festem Punkt
#mit ST_Transform wandelt die Geometrie in Koordinatensystem, sodass GeoFrame es nutzen kann
#mit ST_MakePoint baut einen Punkt (hier Referenzpunkt HB) in den Code ein --> Reihenfolge immer: Longtitude (x), Latitude (y)
#mit ST_SetSRID(geometry,srid) weist einer Geometrie einen SRID zu (Spatial Reference System Identifier) --> ohne SRID weiss PostGIS nicht, wie Entfernungen und Transformationen gerechnet werden sollen.
#mit ST_DWithin(...,500) werden nur die Salons die maximal 500 meter vom Referenzpunkt entfernt sind. (Radius)

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf.head()
# Out:
#        osm_id         shop                 name  distance_meters  \
# 0  4833061523  hairdresser   André Joe Coiffure        72.248308
# 1  4424939218  hairdresser           McCoiffure       111.911775
# 2  4244059289  hairdresser  Art Coiffure Kaiser       133.709897
# 3  4424939145  hairdresser                Saleh       151.350895
# 4   693318659  hairdresser     Coiffeur Insieme       168.239954
#
#                        geom
# 0  POINT (8.54016 47.37774)
# 1  POINT (8.53791 47.37791)
# 2  POINT (8.53788 47.37745)
# 3  POINT (8.54071 47.37709)
# 4  POINT (8.53992 47.37664)

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=16, 
               tiles='ESRIWorldImagery')

# Map settings
folium.GeoJson(
    gdf,
    name='map'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a0baf9485cac2d5436949fb87826853 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a0baf9485cac2d5436949fb87826853&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a0baf9485cac2d5436949fb87826853 = L.map(
#                 &quot;map_4a0baf9485cac2d5436949fb87826853&quot;,
#                 {
#                     center: [47.37697799452545, 8.540641408333332],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e89b84b37a66e87defeed533abf445e = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e89b84b37a66e87defeed533abf445e.addTo(map_4a0baf9485cac2d5436949fb87826853);
#
#
#
#         function geo_json_6e477034f3ae10f3c6f665ca51184bea_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_6e477034f3ae10f3c6f665ca51184bea = L.geoJson(null, {
#                 onEachFeature: geo_json_6e477034f3ae10f3c6f665ca51184bea_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_6e477034f3ae10f3c6f665ca51184bea_add (data) {
#             geo_json_6e477034f3ae10f3c6f665ca51184bea
#                 .addData(data);
#         }
#             geo_json_6e477034f3ae10f3c6f665ca51184bea_add({&quot;bbox&quot;: [8.535649, 47.373807500081696, 8.5454687, 47.3806169000802], &quot;features&quot;: [{&quot;bbox&quot;: [8.540159099999999, 47.37773990008085, 8.540159099999999, 47.37773990008085], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.540159099999999, 47.37773990008085], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 72.24830774, &quot;name&quot;: &quot;Andr\u00e9 Joe Coiffure&quot;, &quot;osm_id&quot;: 4833061523, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5379091, 47.3779077000808, 8.5379091, 47.3779077000808], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5379091, 47.3779077000808], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 111.91177514, &quot;name&quot;: &quot;McCoiffure&quot;, &quot;osm_id&quot;: 4424939218, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.537875800000002, 47.3774487000809, 8.537875800000002, 47.3774487000809], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.537875800000002, 47.3774487000809], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 133.70989703, &quot;name&quot;: &quot;Art Coiffure Kaiser&quot;, &quot;osm_id&quot;: 4244059289, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5407058, 47.37708990008098, 8.5407058, 47.37708990008098], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5407058, 47.37708990008098], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 151.35089497, &quot;name&quot;: &quot;Saleh&quot;, &quot;osm_id&quot;: 4424939145, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5399187, 47.376635300081084, 8.5399187, 47.376635300081084], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5399187, 47.376635300081084], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 168.2399539, &quot;name&quot;: &quot;Coiffeur Insieme&quot;, &quot;osm_id&quot;: 693318659, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.540674899999999, 47.37633050008117, 8.540674899999999, 47.37633050008117], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.540674899999999, 47.37633050008117], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 220.3308624, &quot;name&quot;: &quot;Perruso&quot;, &quot;osm_id&quot;: 7057868108, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5369503, 47.37931030008048, 8.5369503, 47.37931030008048], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5369503, 47.37931030008048], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 226.

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('IP Address:', socket.gethostbyname(socket.gethostname()))
print('-----------------------------------')
